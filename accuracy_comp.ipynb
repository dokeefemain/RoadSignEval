# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(0.294,0.86399, label = "YOLO")
plt.scatter(1.5934,0.87766, label="Faster IRV2")
plt.title("mAP vs Execution Time")
plt.ylim([0,1])
plt.xlabel("Execution Time (s)")
plt.ylabel("mAP")
plt.legend(loc="lower right")
