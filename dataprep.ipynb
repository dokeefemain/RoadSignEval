# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image

# %%
df = pd.read_csv("lib/datasets/LISA/LISA/allAnnotations.csv",delimiter=";")
df
# Out:
#                                                Filename   Annotation tag  \
# 0     aiua120214-0/frameAnnotations-DataLog02142012_...             stop
# 1     aiua120214-0/frameAnnotations-DataLog02142012_...  speedLimitUrdbl
# 2     aiua120214-0/frameAnnotations-DataLog02142012_...             stop
# 3     aiua120214-0/frameAnnotations-DataLog02142012_...     speedLimit25
# 4     aiua120214-0/frameAnnotations-DataLog02142012_...     speedLimit25
# ...                                                 ...              ...
# 7850  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7851  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7852  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7853  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
# 7854  vid9/frameAnnotations-MVI_0121.MOV_annotations...     speedLimit35
#
#       Upper left corner X  Upper left corner Y  Lower right corner X  \
# ...

# %%
names = df["Filename"].unique().tolist()
train, test = train_test_split(names,test_size=0.2)
train, val = train_test_split(train,test_size=0.25)

# %%
with open("lib/datasets/train.txt", 'w') as file:
    file.write('\n'.join(train))
with open("lib/datasets/test.txt", 'w') as file:
    file.write('\n'.join(test))
with open("lib/datasets/val.txt", 'w') as file:
    file.write('\n'.join(val))

# %%
file = open("lib/datasets/train.txt")
data = file.read()
train = data.replace("\n", " ").split()
train
# Out:
# ['vid5/frameAnnotations-vid_cmp2.avi_annotations/speedLimit_1323822919.avi_image4.png',
#  'aiua120214-0/frameAnnotations-DataLog02142012_external_camera.avi_annotations/speedLimit_1330547196.avi_image3.png',
#  'vid5/frameAnnotations-vid_cmp2.avi_annotations/school_1323824526.avi_image5.png',
#  'aiua120306-1/frameAnnotations-DataLog02142012_003_external_camera.avi_annotations/zoneAhead25_1333395968.avi_image7.png',
#  'aiua120306-0/frameAnnotations-DataLog02142012_002_external_camera.avi_annotations/keepRight_1333393691.avi_image10.png',
#  'aiua120214-0/frameAnnotations-DataLog02142012_external_camera.avi_annotations/speedLimit_1330546092.avi_image5.png',
#  'vid6/frameAnnotations-MVI_0071.MOV_annotations/stop_1323896899.avi_image9.png',
#  'vid4/frameAnnotations-vid_cmp2.avi_annotations/speedLimit_1323822585.avi_image11.png',
#  'vid5/frameAnnotations-vid_cmp2.avi_annotations/pedestrian_1323822718.avi_image22.png',
# ...
